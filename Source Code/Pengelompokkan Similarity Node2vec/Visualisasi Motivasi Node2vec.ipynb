# %%
# %matplotlib inline

import pandas as pd
import networkx as nx

import warnings
from operator import itemgetter
from networkx.algorithms import community

# %%
from sklearn.manifold import TSNE
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from node2vec import Node2Vec
sns.set_style("whitegrid")

from operator import is_not
from functools import partial

# %%
df = pd.read_csv("node2vec-motivasi.csv")
df
# Out:
#       partai                                            kalimat       kata0  \
# 0     Golkar  abdi  maju  bangsa  juang  aspirasi  daerah   ...      daerah
# 1        PAN  wakil  rakyat  daerah  sumut  3  benar2  juang...      daerah
# 2        PSI  awas  birokrasi  perintah  daerah             ...      daerah
# 3     Hanura  berkonteribusi  daerah  pilih  daerah         ...      daerah
# 4       PDIP  ambil  ambil  putus  bijak  membangut  daerah ...      daerah
# 5   Berkarya  maju  daerah  klungkung                       ...      daerah
# 6        PKB  bangun  daerah  lahir                         ...      daerah
# 7   Demokrat     bangun  daerah                                      daerah
# 8        PPP  bantu  bangun  daerah                         ...      daerah
# 9     Garuda  muda  guna  maju  bangsa  indonesia  daerah  b...      daerah
# 10      PKPI  abdi  bangun  sumbar  daerah  pesisir         ...      daerah
# 11  Gerindra  motivasi  aju  calon  anggota  dpr  aceh  part...  masyarakat
# 12       PBB  peran  aktif  bangun  masyarakat              ...  masyarakat
# 13    Nasdem  abdi  negara  masyarakat  wakil  baik  sikap  ...  masyarakat
# 14       PKS  jadi  sambung  realisasi  aspirasi  masyarakat...  masyarakat
# 15    Golkar  juang  penting  rakyat  indonesia             ...      rakyat
# 16  Gerindra  abdi  juang  sejahtera  rakyat  aceh          ...      rakyat
# 17       PAN  wakil  rakyat  daerah  sumut  3  benar2  juang...      rakyat
# 18       PSI  juang  aspirasi  rakyat  capai  indonesia  sej...      rakyat
# 19       PKS    khidmat  rakyat                                      rakyat
# 20       PPP  wujud  tingkat  ekonomi  rakyat  wujud  adil  ...      rakyat
# 21      PDIP  wujud  rakyat  sejahtera  bijak  perintah     ...      rakyat
# 22      PKPI            rakyat                                       rakyat
# 23  Demokrat  wakil  rakyat  kualitas                       ...      rakyat
# 24    Nasdem  juang  maju  sejahtera  bangsa  indonesia     ...       juang
# 25    Garuda  juang  penting  rakyat                        ...     penting
# 26  Gerindra  motivasi  aju  calon  anggota  dpr  aceh  part...  masyarakat
# 27    Garuda  mensejahtrakan  masyarakat                    ...  masyarakat
# 28       PKB  corong  masyarakat  suara  penting  public  in...  masyarakat
# 29       PSI  realisasi  cita  cita  bakti  bangsa  negara  ...  masyarakat
# 30    Golkar  tingkat  kesejahtraan  masyarakat  daya  ekono...  masyarakat
# 31       PPP  sejahtera  masyarakat                         ...  masyarakat
# 32  Berkarya  juang  hak  hak  rakyat  sambung  aspirasi  ma...  masyarakat
# 33       PBB  peran  aktif  bangun  masyarakat              ...  masyarakat
# 34    Nasdem  abdi  negara  masyarakat  wakil  baik  sikap  ...  masyarakat
# 35       PKS  jadi  sambung  realisasi  aspirasi  masyarakat...  masyarakat
# 36       PAN  juang  masyarakat  dapil  hidup               ...  masyarakat
# 37  Demokrat  motivasi  calon  anggota  legislatif  provinsi...  masyarakat
# 38      PDIP  salur  aspirasi  masyarakat  nusa  tenggara  t...  masyarakat
# 39    Hanura   abdi  masyarakat                                  masyarakat
# 40      PKPI   abdi  masyarakat                                  masyarakat
#
#          kata1      kata2      kata3      kata4                 kategori
# 0   masyarakat  perempuan       kaum    ekonomi  Perekonomian Masyarakat
# 1   masyarakat  perempuan       kaum       kaum  Perekonomian Masyarakat
# 2    perempuan       kaum    ekonomi    ekonomi  Perekonomian Masyarakat
# 3    perempuan       kaum    ekonomi    ekonomi  Perekonomian Masyarakat
# 4   masyarakat  perempuan       kaum    ekonomi  Perekonomian Masyarakat
# 5    perempuan       kaum    ekonomi    ekonomi  Perekonomian Masyarakat
# 6    perempuan       kaum    ekonomi    ekonomi  Perekonomian Masyarakat
# 7    perempuan       kaum    ekonomi    ekonomi  Perekonomian Masyarakat
# 8    perempuan    ekonomi    ekonomi    ekonomi  Perekonomian Masyarakat
# 9    perempuan       kaum    ekonomi    ekonomi  Perekonomian Masyarakat
# 10  masyarakat  perempuan       kaum    ekonomi  Perekonomian Masyarakat
# 11   perempuan       kaum    ekonomi    ekonomi  Perekonomian Masyarakat
# 12   perempuan       kaum    ekonomi    ekonomi  Perekonomian Masyarakat
# 13   perempuan       kaum    ekonomi       maju  Perekonomian Masyarakat
# 14   perempuan       kaum    ekonomi       maju  Perekonomian Masyarakat
# 15       juang    penting  perempuan       maju     Kesejahteraan Rakyat
# 16       juang    penting  perempuan       maju     Kesejahteraan Rakyat
# 17       juang    penting  perempuan       maju     Kesejahteraan Rakyat
# 18       juang    penting  perempuan       maju     Kesejahteraan Rakyat
# 19       juang  perempuan  perempuan  perempuan     Kesejahteraan Rakyat
# 20   perempuan       maju       maju       maju     Kesejahteraan Rakyat
# 21     penting  perempuan       maju       maju     Kesejahteraan Rakyat
# 22     penting       maju       maju       maju     Kesejahteraan Rakyat
# 23     penting  perempuan  perempuan  perempuan     Kesejahteraan Rakyat
# 24   perempuan  perempuan  perempuan  perempuan     Kesejahteraan Rakyat
# 25     penting    penting    penting    penting     Kesejahteraan Rakyat
# 26        anak      juang       kota       kota           Isu Pendidikan
# 27        anak      juang       kota       kota           Isu Pendidikan
# 28       juang      didik      didik      didik           Isu Pendidikan
# 29       juang       kota       kota       kota           Isu Pendidikan
# 30       juang       kota       kota       kota           Isu Pendidikan
# 31        anak      juang      didik       kota           Isu Pendidikan
# 32        anak      juang      didik       kota           Isu Pendidikan
# 33       juang      juang      juang      juang           Isu Pendidikan
# 34       juang      didik      didik      didik           Isu Pendidikan
# 35       juang      didik       kota       kota           Isu Pendidikan
# 36       juang      didik       kota       kota           Isu Pendidikan
# 37        anak      juang       kota       kota           Isu Pendidikan
# 38       juang       kota       kota       kota           Isu Pendidikan
# 39        anak      juang      didik       kota           Isu Pendidikan
# 40       juang      didik       kota       kota           Isu Pendidikan

# %%
g = nx.from_pandas_edgelist(df, source='kategori', target='kata0')
g = nx.from_pandas_edgelist(df, source='kategori', target='kata1')
g = nx.from_pandas_edgelist(df, source='kategori', target='kata2')
g = nx.from_pandas_edgelist(df, source='kategori', target='kata3')
g = nx.from_pandas_edgelist(df, source='kategori', target='kata4')

# %%
g = nx.from_pandas_edgelist(df, source='partai', target='kategori')

# %%
dfpartaikata0 = df[['partai','kata0']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata0clean = dfpartaikata0.dropna()
dfpartaikata0clean
listpartaikata0 = dfpartaikata0clean.values.tolist()
listpartaikata0
# Out:
# [['Golkar', 'daerah'],
#  ['PAN', 'daerah'],
#  ['PSI', 'daerah'],
#  ['Hanura', 'daerah'],
#  ['PDIP', 'daerah'],
#  ['Berkarya', 'daerah'],
#  ['PKB', 'daerah'],
#  ['Demokrat', 'daerah'],
#  ['PPP', 'daerah'],
#  ['Garuda', 'daerah'],
#  ['PKPI', 'daerah'],
#  ['Gerindra', 'masyarakat'],
#  ['PBB', 'masyarakat'],
#  ['Nasdem', 'masyarakat'],
#  ['PKS', 'masyarakat'],
#  ['Golkar', 'rakyat'],
#  ['Gerindra', 'rakyat'],
#  ['PAN', 'rakyat'],
#  ['PSI', 'rakyat'],
#  ['PKS', 'rakyat'],
#  ['PPP', 'rakyat'],
#  ['PDIP', 'rakyat'],
#  ['PKPI', 'rakyat'],
#  ['Demokrat', 'rakyat'],
#  ['Nasdem', 'juang'],
#  ['Garuda', 'penting'],
#  ['Gerindra', 'masyarakat'],
#  ['Garuda', 'masyarakat'],
#  ['PKB', 'masyarakat'],
#  ['PSI', 'masyarakat'],
#  ['Golkar', 'masyarakat'],
#  ['PPP', 'masyarakat'],
#  ['Berkarya', 'masyarakat'],
#  ['PBB', 'masyarakat'],
#  ['Nasdem', 'masyarakat'],
#  ['PKS', 'masyarakat'],
#  ['PAN', 'masyarakat'],
#  ['Demokrat', 'masyarakat'],
#  ['PDIP', 'masyarakat'],
#  ['Hanura', 'masyarakat'],
#  ['PKPI', 'masyarakat']]

# %%
dfpartaikata1 = df[['partai','kata1']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata1clean = dfpartaikata1.dropna()
dfpartaikata1clean
listpartaikata1 = dfpartaikata1clean.values.tolist()
listpartaikata1
# Out:
# [['Golkar', 'masyarakat'],
#  ['PAN', 'masyarakat'],
#  ['PSI', 'perempuan'],
#  ['Hanura', 'perempuan'],
#  ['PDIP', 'masyarakat'],
#  ['Berkarya', 'perempuan'],
#  ['PKB', 'perempuan'],
#  ['Demokrat', 'perempuan'],
#  ['PPP', 'perempuan'],
#  ['Garuda', 'perempuan'],
#  ['PKPI', 'masyarakat'],
#  ['Gerindra', 'perempuan'],
#  ['PBB', 'perempuan'],
#  ['Nasdem', 'perempuan'],
#  ['PKS', 'perempuan'],
#  ['Golkar', 'juang'],
#  ['Gerindra', 'juang'],
#  ['PAN', 'juang'],
#  ['PSI', 'juang'],
#  ['PKS', 'juang'],
#  ['PPP', 'perempuan'],
#  ['PDIP', 'penting'],
#  ['PKPI', 'penting'],
#  ['Demokrat', 'penting'],
#  ['Nasdem', 'perempuan'],
#  ['Garuda', 'penting'],
#  ['Gerindra', 'anak'],
#  ['Garuda', 'anak'],
#  ['PKB', 'juang'],
#  ['PSI', 'juang'],
#  ['Golkar', 'juang'],
#  ['PPP', 'anak'],
#  ['Berkarya', 'anak'],
#  ['PBB', 'juang'],
#  ['Nasdem', 'juang'],
#  ['PKS', 'juang'],
#  ['PAN', 'juang'],
#  ['Demokrat', 'anak'],
#  ['PDIP', 'juang'],
#  ['Hanura', 'anak'],
#  ['PKPI', 'juang']]

# %%
dfpartaikata2 = df[['partai','kata2']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata2clean = dfpartaikata2.dropna()
dfpartaikata2clean
listpartaikata2 = dfpartaikata2clean.values.tolist()
listpartaikata2
# Out:
# [['Golkar', 'perempuan'],
#  ['PAN', 'perempuan'],
#  ['PSI', 'kaum'],
#  ['Hanura', 'kaum'],
#  ['PDIP', 'perempuan'],
#  ['Berkarya', 'kaum'],
#  ['PKB', 'kaum'],
#  ['Demokrat', 'kaum'],
#  ['PPP', 'ekonomi'],
#  ['Garuda', 'kaum'],
#  ['PKPI', 'perempuan'],
#  ['Gerindra', 'kaum'],
#  ['PBB', 'kaum'],
#  ['Nasdem', 'kaum'],
#  ['PKS', 'kaum'],
#  ['Golkar', 'penting'],
#  ['Gerindra', 'penting'],
#  ['PAN', 'penting'],
#  ['PSI', 'penting'],
#  ['PKS', 'perempuan'],
#  ['PPP', 'maju'],
#  ['PDIP', 'perempuan'],
#  ['PKPI', 'maju'],
#  ['Demokrat', 'perempuan'],
#  ['Nasdem', 'perempuan'],
#  ['Garuda', 'penting'],
#  ['Gerindra', 'juang'],
#  ['Garuda', 'juang'],
#  ['PKB', 'didik'],
#  ['PSI', 'kota'],
#  ['Golkar', 'kota'],
#  ['PPP', 'juang'],
#  ['Berkarya', 'juang'],
#  ['PBB', 'juang'],
#  ['Nasdem', 'didik'],
#  ['PKS', 'didik'],
#  ['PAN', 'didik'],
#  ['Demokrat', 'juang'],
#  ['PDIP', 'kota'],
#  ['Hanura', 'juang'],
#  ['PKPI', 'didik']]

# %%
dfpartaikata3 = df[['partai','kata3']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata3clean = dfpartaikata3.dropna()
dfpartaikata3clean
listpartaikata3 = dfpartaikata3clean.values.tolist()
listpartaikata3
# Out:
# [['Golkar', 'kaum'],
#  ['PAN', 'kaum'],
#  ['PSI', 'ekonomi'],
#  ['Hanura', 'ekonomi'],
#  ['PDIP', 'kaum'],
#  ['Berkarya', 'ekonomi'],
#  ['PKB', 'ekonomi'],
#  ['Demokrat', 'ekonomi'],
#  ['PPP', 'ekonomi'],
#  ['Garuda', 'ekonomi'],
#  ['PKPI', 'kaum'],
#  ['Gerindra', 'ekonomi'],
#  ['PBB', 'ekonomi'],
#  ['Nasdem', 'ekonomi'],
#  ['PKS', 'ekonomi'],
#  ['Golkar', 'perempuan'],
#  ['Gerindra', 'perempuan'],
#  ['PAN', 'perempuan'],
#  ['PSI', 'perempuan'],
#  ['PKS', 'perempuan'],
#  ['PPP', 'maju'],
#  ['PDIP', 'maju'],
#  ['PKPI', 'maju'],
#  ['Demokrat', 'perempuan'],
#  ['Nasdem', 'perempuan'],
#  ['Garuda', 'penting'],
#  ['Gerindra', 'kota'],
#  ['Garuda', 'kota'],
#  ['PKB', 'didik'],
#  ['PSI', 'kota'],
#  ['Golkar', 'kota'],
#  ['PPP', 'didik'],
#  ['Berkarya', 'didik'],
#  ['PBB', 'juang'],
#  ['Nasdem', 'didik'],
#  ['PKS', 'kota'],
#  ['PAN', 'kota'],
#  ['Demokrat', 'kota'],
#  ['PDIP', 'kota'],
#  ['Hanura', 'didik'],
#  ['PKPI', 'kota']]

# %%
dfpartaikata4 = df[['partai','kata4']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata4clean = dfpartaikata4.dropna()
dfpartaikata4clean
listpartaikata4 = dfpartaikata4clean.values.tolist()
listpartaikata4
# Out:
# [['Golkar', 'ekonomi'],
#  ['PAN', 'kaum'],
#  ['PSI', 'ekonomi'],
#  ['Hanura', 'ekonomi'],
#  ['PDIP', 'ekonomi'],
#  ['Berkarya', 'ekonomi'],
#  ['PKB', 'ekonomi'],
#  ['Demokrat', 'ekonomi'],
#  ['PPP', 'ekonomi'],
#  ['Garuda', 'ekonomi'],
#  ['PKPI', 'ekonomi'],
#  ['Gerindra', 'ekonomi'],
#  ['PBB', 'ekonomi'],
#  ['Nasdem', 'maju'],
#  ['PKS', 'maju'],
#  ['Golkar', 'maju'],
#  ['Gerindra', 'maju'],
#  ['PAN', 'maju'],
#  ['PSI', 'maju'],
#  ['PKS', 'perempuan'],
#  ['PPP', 'maju'],
#  ['PDIP', 'maju'],
#  ['PKPI', 'maju'],
#  ['Demokrat', 'perempuan'],
#  ['Nasdem', 'perempuan'],
#  ['Garuda', 'penting'],
#  ['Gerindra', 'kota'],
#  ['Garuda', 'kota'],
#  ['PKB', 'didik'],
#  ['PSI', 'kota'],
#  ['Golkar', 'kota'],
#  ['PPP', 'kota'],
#  ['Berkarya', 'kota'],
#  ['PBB', 'juang'],
#  ['Nasdem', 'didik'],
#  ['PKS', 'kota'],
#  ['PAN', 'kota'],
#  ['Demokrat', 'kota'],
#  ['PDIP', 'kota'],
#  ['Hanura', 'kota'],
#  ['PKPI', 'kota']]

# %%
g.add_edges_from(listpartaikata0,weight=1, label="partaikata0edge")
g.add_edges_from(listpartaikata1,weight=1, label="partaikata1edge")
g.add_edges_from(listpartaikata2,weight=1, label="partaikata2edge")
g.add_edges_from(listpartaikata3,weight=1, label="partaikata3edge")
g.add_edges_from(listpartaikata4,weight=1, label="partaikata3edge")

# %%
labels = [i for i in dict(g.nodes).keys()]
labels = {i:i for i in dict(g.nodes).keys()}
labels
labelsclean = {k: v for k, v in labels.items() if pd.Series(v).notna().all()}
labelsclean
# Out:
# {'Golkar': 'Golkar',
#  'Perekonomian Masyarakat': 'Perekonomian Masyarakat',
#  'PAN': 'PAN',
#  'PSI': 'PSI',
#  'Hanura': 'Hanura',
#  'PDIP': 'PDIP',
#  'Berkarya': 'Berkarya',
#  'PKB': 'PKB',
#  'Demokrat': 'Demokrat',
#  'PPP': 'PPP',
#  'Garuda': 'Garuda',
#  'PKPI': 'PKPI',
#  'Gerindra': 'Gerindra',
#  'PBB': 'PBB',
#  'Nasdem': 'Nasdem',
#  'PKS': 'PKS',
#  'Kesejahteraan Rakyat': 'Kesejahteraan Rakyat',
#  'Isu Pendidikan': 'Isu Pendidikan',
#  'daerah': 'daerah',
#  'masyarakat': 'masyarakat',
#  'rakyat': 'rakyat',
#  'juang': 'juang',
#  'penting': 'penting',
#  'perempuan': 'perempuan',
#  'anak': 'anak',
#  'kaum': 'kaum',
#  'ekonomi': 'ekonomi',
#  'maju': 'maju',
#  'didik': 'didik',
#  'kota': 'kota'}

# %%
fig, ax = plt.subplots(figsize=(19,15))
layout = nx.spring_layout(g,iterations=50)
nx.draw_networkx_nodes(g, layout, ax = ax, labels = True)
nx.draw_networkx_edges(g, layout, ax = ax)
_ = nx.draw_networkx_labels(g, layout, labels, ax=ax)
partaipopuler = [namapartai for namapartai in df.partai if g.degree(namapartai) > 1]
nx.draw_networkx_nodes(g, layout, nodelist=partaipopuler, node_color='orange', node_size=150)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
# Precompute probabilities and generate walks
node2vec = Node2Vec(g, dimensions=50, walk_length=16, num_walks=100, workers=4)
# Out:
# Computing transition probabilities: 100%|██████████| 30/30 [00:00<00:00, 1002.65it/s]

# %%
# EmbedQ
model = node2vec.fit(window=10, min_count=1, batch_words=4)  # Any keywords acceptable by gensim.Word2Vec can be passed, `diemnsions` and `workers` are automatically passed (from the Node2Vec constructor)

# %%
df.partai
# Out:
# 0       Golkar
# 1          PAN
# 2          PSI
# 3       Hanura
# 4         PDIP
# 5     Berkarya
# 6          PKB
# 7     Demokrat
# 8          PPP
# 9       Garuda
# 10        PKPI
# 11    Gerindra
# 12         PBB
# 13      Nasdem
# 14         PKS
# 15      Golkar
# 16    Gerindra
# 17         PAN
# 18         PSI
# 19         PKS
# 20         PPP
# 21        PDIP
# 22        PKPI
# 23    Demokrat
# 24      Nasdem
# 25      Garuda
# 26    Gerindra
# 27      Garuda
# 28         PKB
# 29         PSI
# 30      Golkar
# 31         PPP
# 32    Berkarya
# 33         PBB
# 34      Nasdem
# 35         PKS
# 36         PAN
# 37    Demokrat
# 38        PDIP
# 39      Hanura
# 40        PKPI
# Name: partai, dtype: object

# %%
used = set()
nodepartai = [x for x in df.partai if x not in used and (used.add(x) or True)]
#nodepartai = set(nodepartai)
nodepartai
# Out:
# ['Golkar',
#  'PAN',
#  'PSI',
#  'Hanura',
#  'PDIP',
#  'Berkarya',
#  'PKB',
#  'Demokrat',
#  'PPP',
#  'Garuda',
#  'PKPI',
#  'Gerindra',
#  'PBB',
#  'Nasdem',
#  'PKS']

# %%
nodepartai2 = [x for x in df.partai]
nodepartai2
# Out:
# ['Golkar',
#  'PAN',
#  'PSI',
#  'Hanura',
#  'PDIP',
#  'Berkarya',
#  'PKB',
#  'Demokrat',
#  'PPP',
#  'Garuda',
#  'PKPI',
#  'Gerindra',
#  'PBB',
#  'Nasdem',
#  'PKS',
#  'Golkar',
#  'Gerindra',
#  'PAN',
#  'PSI',
#  'PKS',
#  'PPP',
#  'PDIP',
#  'PKPI',
#  'Demokrat',
#  'Nasdem',
#  'Garuda',
#  'Gerindra',
#  'Garuda',
#  'PKB',
#  'PSI',
#  'Golkar',
#  'PPP',
#  'Berkarya',
#  'PBB',
#  'Nasdem',
#  'PKS',
#  'PAN',
#  'Demokrat',
#  'PDIP',
#  'Hanura',
#  'PKPI']

# %%
nodekategori = [x for x in df.kategori]
#nodepartai = set(nodepartai)
nodekategori
# Out:
# ['Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Perekonomian Masyarakat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Kesejahteraan Rakyat',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan',
#  'Isu Pendidikan']

# %%
used = set()
#uniq = ['PARTAI_KEADILAN_SEJAHTERA']
uniq2 = [x for x in nodepartai if x not in used and (used.add(x) or True)]
uniq2
# Out:
# ['Golkar',
#  'PAN',
#  'PSI',
#  'Hanura',
#  'PDIP',
#  'Berkarya',
#  'PKB',
#  'Demokrat',
#  'PPP',
#  'Garuda',
#  'PKPI',
#  'Gerindra',
#  'PBB',
#  'Nasdem',
#  'PKS']

# %%
embeddings = np.array([model.wv[x] for x in nodepartai2])
embeddings
# Out:
# array([[ 0.19847761,  0.12044484, -0.23170608, ..., -0.2672701 ,
#         -0.13982777,  0.06338124],
#        [ 0.19997129,  0.13142014, -0.21903248, ..., -0.26508772,
#         -0.12883642,  0.08174257],
#        [ 0.2077145 ,  0.1353401 , -0.23460492, ..., -0.26712584,
#         -0.13846198,  0.06811776],
#        ...,
#        [ 0.21158089,  0.11879451, -0.22728942, ..., -0.26112926,
#         -0.12897761,  0.06717324],
#        [ 0.22700636,  0.15797366, -0.22805941, ..., -0.2759292 ,
#         -0.11173177,  0.06892713],
#        [ 0.21746367,  0.13487914, -0.22773282, ..., -0.2589665 ,
#         -0.12980278,  0.0737252 ]], dtype=float32)

# %%
tsne = TSNE(n_components=2, random_state=7, perplexity=15)
embeddings_2d = tsne.fit_transform(embeddings)

# %%
warna_kategori = {
    'Perekonomian Masyarakat':'indianred',
    'Kesejahteraan Rakyat':'mediumseagreen',
    'Isu Pendidikan':'cornflowerblue'}
    #'Partai_Keadilan_Sejahtera':'yellow',
    #'Partai_Kebangkitan_Bangsa':'darkcyan',
    #'Partai_Persatuan_Pembangunan':'steelblue'}

df['color'] = df['kategori'].apply(lambda x: warna_kategori[x])
warna_partai=dict(zip(df['partai'],df['color']))
colors = [warna_kategori[x] for x in df.kategori]

# %%
figure = plt.figure(figsize=(11,9))

ax = figure.add_subplot(111)

ax.scatter(embeddings_2d[:,0], embeddings_2d[:,1], c=colors)

i = 0
for partaiku in nodepartai2:
    ax.annotate(partaiku, (embeddings_2d[i,0], embeddings_2d[i, 1]))
    i=i+1
    

partai_legend=[mpatches.Patch(color=color, label=df.partai.unique()) for df.partai, color in warna_kategori.items()]
ax.legend(handles=partai_legend);

# %%
preds = nx.jaccard_coefficient(g)
for u, v, p in preds:
    if (p>0.9):
        print(u, v, p)
# Out:
# juang Isu Pendidikan 1.0
# juang Perekonomian Masyarakat 1.0
# juang masyarakat 1.0
# juang ekonomi 0.9333333333333333
# juang kaum 0.9333333333333333
# juang perempuan 1.0
# Golkar PKPI 0.9285714285714286
# Golkar PDIP 1.0
# Golkar PSI 1.0
# PDIP PKPI 0.9285714285714286
# PDIP PSI 1.0
# Garuda Demokrat 0.9230769230769231
# Perekonomian Masyarakat Isu Pendidikan 1.0
# Perekonomian Masyarakat ekonomi 0.9333333333333333
# Perekonomian Masyarakat masyarakat 1.0
# Perekonomian Masyarakat kaum 0.9333333333333333
# Perekonomian Masyarakat perempuan 1.0
# masyarakat Isu Pendidikan 1.0
# masyarakat ekonomi 0.9333333333333333
# masyarakat kaum 0.9333333333333333
# masyarakat perempuan 1.0
# PSI PKPI 0.9285714285714286
# Hanura Berkarya 1.0
# PKPI PAN 0.9285714285714286
# Isu Pendidikan ekonomi 0.9333333333333333
# Isu Pendidikan kaum 0.9333333333333333
# Isu Pendidikan perempuan 1.0
# ekonomi perempuan 0.9333333333333333
# perempuan kaum 0.9333333333333333

# %%
import matplotlib.pyplot as plt
pos = nx.spring_layout(g)
node_color = [20000.0 * g.degree(v) for v in g]
node_size =  [v * 100 for v in degree_dict.values()]
plt.figure(figsize=(20,20))
nx.draw_networkx(g, pos=pos, with_labels=True,node_color=node_color,node_size=node_size )
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-656b85745c20> in <module>
#       2 pos = nx.spring_layout(g)
#       3 node_color = [20000.0 * g.degree(v) for v in g]
# ----> 4 node_size =  [v * 100 for v in degree_dict.values()]
#       5 plt.figure(figsize=(20,20))
#       6 nx.draw_networkx(g, pos=pos, with_labels=True,node_color=node_color,node_size=node_size )
#
# NameError: name 'degree_dict' is not defined
