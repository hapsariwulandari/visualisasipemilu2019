# %%
# %matplotlib inline

import pandas as pd
import networkx as nx

import warnings
from operator import itemgetter
from networkx.algorithms import community

# %%
from sklearn.manifold import TSNE
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from node2vec import Node2Vec
sns.set_style("whitegrid")

from operator import is_not
from functools import partial

# %%
df = pd.read_csv("node2vec-target.csv")
df
# Out:
#       partai                                            kalimat       kata0  \
# 0   Demokrat             juang aspirasi rakyat aceh indonesia         juang
# 1     Nasdem                     juang hak hak kaum perempuan         juang
# 2   Gerindra              juang hak hak perempuan bangun aceh         juang
# 3     Golkar             juang aspirasi rakyat aceh indonesia         juang
# 4        PKS  1 juang program aksi gerindra tingkat sehat ma...       juang
# 5        PPP                                1 juang misi pks          juang
# 6        PKB                   juang wujud masyarakat cerdas          juang
# 7        PSI             juang sejahtera buruh kerja keluarga         juang
# 8        PAN  a dorong tinjau ulang amandemen uud cita cita ...       juang
# 9       PKPI  juang disparitas ekonomi kabupaten cianjur uta...       juang
# 10    Garuda                         juang hak hak perempuan          juang
# 11    Hanura                juang kaum perempuan daya mandiri         juang
# 12  Berkarya  a dorong tinjau ulang amandemen uud cita cita ...       juang
# 13      PDIP                   juang aspirasi perempuan anak          juang
# 14       PBB                      juang sejahtera masyarakat          juang
# 15  Gerindra  lanjut  didik  bas  dayah  bantu  masyarakat  ...  masyarakat
# 16  Berkarya  bantu  masyarakat  kalang                     ...  masyarakat
# 17       PKS  1  wujud  bangun  dampak  nyata  sejahtera  ma...  masyarakat
# 18       PKB  jalan  amanah  aspirasi  masyarakat           ...  masyarakat
# 19    Golkar  masyarakat  perempuan                         ...  masyarakat
# 20       PSI  layan  masyarakat                             ...  masyarakat
# 21       PPP  sarana  langsung  terima  aspirasi  masyarakat...  masyarakat
# 22      PKPI  kuat  peran  masyarakat  bangun  ekonomi  nasi...  masyarakat
# 23      PDIP  layan  masyarakat                             ...  masyarakat
# 24    Nasdem  tingkat  sumber  daya  manusia  bantu  masyara...  masyarakat
# 25       PAN  juang  aspirasi  masyarakat  dapil  3  jabar  ...  masyarakat
# 26    Garuda  baik  tingkat  bangun  butuh  butuh  dasar  ma...  masyarakat
# 27       PBB  anggota  dewan  awal  aspirasi  masyarakat    ...  masyarakat
# 28    Hanura  masyarakat  mandiri  sejahtera                ...  masyarakat
# 29  Demokrat  bela  penting  masyarakat                     ...  masyarakat
# 30       PPP  isi  contoh  anggota  dpr  dprd  provinsi  dpr...    provinsi
# 31       PSI  isi  contoh  anggota  dpr  dprd  provinsi  dpr...    provinsi
# 32       PKB  bawa  aspirasi  masyarakat  bener  riah  aceh ...    provinsi
# 33    Nasdem  abdi  partai  golkar  oleh  kursi  dpr  r1  da...    provinsi
# 34  Gerindra  abdi  partai  golkar  oleh  kursi  dpr  r1  da...    provinsi
# 35       PAN  isi  contoh  anggota  dpr  dprd  provinsi  dpr...    provinsi
# 36    Golkar  abdi  partai  golkar  oleh  kursi  dpr  r1  da...    provinsi
# 37  Berkarya  abdi  partai  golkar  oleh  kursi  dpr  r1  da...    provinsi
# 38      PDIP  target  sasar  jabat  anggota  legislatif  pro...    provinsi
# 39    Garuda  anggota  dprd  provinsi                       ...    provinsi
# 40       PKS  anggota  dpr  dprd  provinsi  dprd  kab  kota ...    provinsi
# 41    Hanura  isi  contoh  anggota  dpr  dprd  provinsi  dpr...    provinsi
# 42  Demokrat  bantu  aspirasi  masyarakat  kota  denpasar  p...    provinsi
# 43      PKPI  turun  tingkat  miskin  provinsi  banten      ...    provinsi
# 44       PBB  anggota  dprd  provinsi  riau  2019  2024  per...    provinsi
#
#          kata1       kata2       kata3       kata4                  kategori
# 0       bidang      bangun  masyarakat  masyarakat        Pembangunan Daerah
# 1       bangun  masyarakat  masyarakat  masyarakat        Pembangunan Daerah
# 2       bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 3       bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 4       bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 5       bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 6       bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 7       bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 8       bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 9       bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 10      bidang  masyarakat       utara       utara        Pembangunan Daerah
# 11      bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 12      bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 13      bidang      bangun  masyarakat       utara        Pembangunan Daerah
# 14      bidang      bangun  masyarakat  masyarakat        Pembangunan Daerah
# 15     tingkat       pihak    perintah    perintah       Pergerakan Nasional
# 16         hak     tingkat    perintah    perintah       Pergerakan Nasional
# 17         hak     tingkat       pihak    perintah       Pergerakan Nasional
# 18     tingkat       pihak    perintah    perintah       Pergerakan Nasional
# 19     tingkat       pihak    perintah    perintah       Pergerakan Nasional
# 20         hak     tingkat       pihak    perintah       Pergerakan Nasional
# 21     tingkat       pihak    perintah    perintah       Pergerakan Nasional
# 22         hak     tingkat    perintah    perintah       Pergerakan Nasional
# 23         hak     tingkat       pihak    perintah       Pergerakan Nasional
# 24         hak     tingkat       pihak    perintah       Pergerakan Nasional
# 25         hak     tingkat       pihak    perintah       Pergerakan Nasional
# 26         hak     tingkat       pihak    perintah       Pergerakan Nasional
# 27         hak     tingkat     tingkat     tingkat       Pergerakan Nasional
# 28         hak     tingkat       pihak    perintah       Pergerakan Nasional
# 29     tingkat       pihak    perintah    perintah       Pergerakan Nasional
# 30  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 31  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 32  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 33  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 34  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 35  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 36  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 37  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 38  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 39  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 40  masyarakat        dprd      fungsi      fungsi  Peran Anggota Legislatif
# 41  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 42  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 43  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif
# 44  masyarakat      bangun        dprd      fungsi  Peran Anggota Legislatif

# %%
g = nx.from_pandas_edgelist(df, source='kategori', target='kata0')
g = nx.from_pandas_edgelist(df, source='kategori', target='kata1')
g = nx.from_pandas_edgelist(df, source='kategori', target='kata2')
g = nx.from_pandas_edgelist(df, source='kategori', target='kata3')
g = nx.from_pandas_edgelist(df, source='kategori', target='kata4')

# %%
dfpartaikata0 = df[['partai','kata0']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata0clean = dfpartaikata0.dropna()
dfpartaikata0clean
listpartaikata0 = dfpartaikata0clean.values.tolist()
listpartaikata0
# Out:
# [['Demokrat', 'juang'],
#  ['Nasdem', 'juang'],
#  ['Gerindra', 'juang'],
#  ['Golkar', 'juang'],
#  ['PKS', 'juang'],
#  ['PPP', 'juang'],
#  ['PKB', 'juang'],
#  ['PSI', 'juang'],
#  ['PAN', 'juang'],
#  ['PKPI', 'juang'],
#  ['Garuda', 'juang'],
#  ['Hanura', 'juang'],
#  ['Berkarya', 'juang'],
#  ['PDIP', 'juang'],
#  ['PBB', 'juang'],
#  ['Gerindra', 'masyarakat'],
#  ['Berkarya', 'masyarakat'],
#  ['PKS', 'masyarakat'],
#  ['PKB', 'masyarakat'],
#  ['Golkar', 'masyarakat'],
#  ['PSI', 'masyarakat'],
#  ['PPP', 'masyarakat'],
#  ['PKPI', 'masyarakat'],
#  ['PDIP', 'masyarakat'],
#  ['Nasdem', 'masyarakat'],
#  ['PAN', 'masyarakat'],
#  ['Garuda', 'masyarakat'],
#  ['PBB', 'masyarakat'],
#  ['Hanura', 'masyarakat'],
#  ['Demokrat', 'masyarakat'],
#  ['PPP', 'provinsi'],
#  ['PSI', 'provinsi'],
#  ['PKB', 'provinsi'],
#  ['Nasdem', 'provinsi'],
#  ['Gerindra', 'provinsi'],
#  ['PAN', 'provinsi'],
#  ['Golkar', 'provinsi'],
#  ['Berkarya', 'provinsi'],
#  ['PDIP', 'provinsi'],
#  ['Garuda', 'provinsi'],
#  ['PKS', 'provinsi'],
#  ['Hanura', 'provinsi'],
#  ['Demokrat', 'provinsi'],
#  ['PKPI', 'provinsi'],
#  ['PBB', 'provinsi']]

# %%
dfpartaikata1 = df[['partai','kata1']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata1clean = dfpartaikata1.dropna()
dfpartaikata1clean
listpartaikata1 = dfpartaikata1clean.values.tolist()
listpartaikata1
# Out:
# [['Demokrat', 'bidang'],
#  ['Nasdem', 'bangun'],
#  ['Gerindra', 'bidang'],
#  ['Golkar', 'bidang'],
#  ['PKS', 'bidang'],
#  ['PPP', 'bidang'],
#  ['PKB', 'bidang'],
#  ['PSI', 'bidang'],
#  ['PAN', 'bidang'],
#  ['PKPI', 'bidang'],
#  ['Garuda', 'bidang'],
#  ['Hanura', 'bidang'],
#  ['Berkarya', 'bidang'],
#  ['PDIP', 'bidang'],
#  ['PBB', 'bidang'],
#  ['Gerindra', 'tingkat'],
#  ['Berkarya', 'hak'],
#  ['PKS', 'hak'],
#  ['PKB', 'tingkat'],
#  ['Golkar', 'tingkat'],
#  ['PSI', 'hak'],
#  ['PPP', 'tingkat'],
#  ['PKPI', 'hak'],
#  ['PDIP', 'hak'],
#  ['Nasdem', 'hak'],
#  ['PAN', 'hak'],
#  ['Garuda', 'hak'],
#  ['PBB', 'hak'],
#  ['Hanura', 'hak'],
#  ['Demokrat', 'tingkat'],
#  ['PPP', 'masyarakat'],
#  ['PSI', 'masyarakat'],
#  ['PKB', 'masyarakat'],
#  ['Nasdem', 'masyarakat'],
#  ['Gerindra', 'masyarakat'],
#  ['PAN', 'masyarakat'],
#  ['Golkar', 'masyarakat'],
#  ['Berkarya', 'masyarakat'],
#  ['PDIP', 'masyarakat'],
#  ['Garuda', 'masyarakat'],
#  ['PKS', 'masyarakat'],
#  ['Hanura', 'masyarakat'],
#  ['Demokrat', 'masyarakat'],
#  ['PKPI', 'masyarakat'],
#  ['PBB', 'masyarakat']]

# %%
dfpartaikata2 = df[['partai','kata2']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata2clean = dfpartaikata2.dropna()
dfpartaikata2clean
listpartaikata2 = dfpartaikata2clean.values.tolist()
listpartaikata2
# Out:
# [['Demokrat', 'bangun'],
#  ['Nasdem', 'masyarakat'],
#  ['Gerindra', 'bangun'],
#  ['Golkar', 'bangun'],
#  ['PKS', 'bangun'],
#  ['PPP', 'bangun'],
#  ['PKB', 'bangun'],
#  ['PSI', 'bangun'],
#  ['PAN', 'bangun'],
#  ['PKPI', 'bangun'],
#  ['Garuda', 'masyarakat'],
#  ['Hanura', 'bangun'],
#  ['Berkarya', 'bangun'],
#  ['PDIP', 'bangun'],
#  ['PBB', 'bangun'],
#  ['Gerindra', 'pihak'],
#  ['Berkarya', 'tingkat'],
#  ['PKS', 'tingkat'],
#  ['PKB', 'pihak'],
#  ['Golkar', 'pihak'],
#  ['PSI', 'tingkat'],
#  ['PPP', 'pihak'],
#  ['PKPI', 'tingkat'],
#  ['PDIP', 'tingkat'],
#  ['Nasdem', 'tingkat'],
#  ['PAN', 'tingkat'],
#  ['Garuda', 'tingkat'],
#  ['PBB', 'tingkat'],
#  ['Hanura', 'tingkat'],
#  ['Demokrat', 'pihak'],
#  ['PPP', 'bangun'],
#  ['PSI', 'bangun'],
#  ['PKB', 'bangun'],
#  ['Nasdem', 'bangun'],
#  ['Gerindra', 'bangun'],
#  ['PAN', 'bangun'],
#  ['Golkar', 'bangun'],
#  ['Berkarya', 'bangun'],
#  ['PDIP', 'bangun'],
#  ['Garuda', 'bangun'],
#  ['PKS', 'dprd'],
#  ['Hanura', 'bangun'],
#  ['Demokrat', 'bangun'],
#  ['PKPI', 'bangun'],
#  ['PBB', 'bangun']]

# %%
dfpartaikata3 = df[['partai','kata3']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata3clean = dfpartaikata3.dropna()
dfpartaikata3clean
listpartaikata3 = dfpartaikata3clean.values.tolist()
listpartaikata3
# Out:
# [['Demokrat', 'masyarakat'],
#  ['Nasdem', 'masyarakat'],
#  ['Gerindra', 'masyarakat'],
#  ['Golkar', 'masyarakat'],
#  ['PKS', 'masyarakat'],
#  ['PPP', 'masyarakat'],
#  ['PKB', 'masyarakat'],
#  ['PSI', 'masyarakat'],
#  ['PAN', 'masyarakat'],
#  ['PKPI', 'masyarakat'],
#  ['Garuda', 'utara'],
#  ['Hanura', 'masyarakat'],
#  ['Berkarya', 'masyarakat'],
#  ['PDIP', 'masyarakat'],
#  ['PBB', 'masyarakat'],
#  ['Gerindra', 'perintah'],
#  ['Berkarya', 'perintah'],
#  ['PKS', 'pihak'],
#  ['PKB', 'perintah'],
#  ['Golkar', 'perintah'],
#  ['PSI', 'pihak'],
#  ['PPP', 'perintah'],
#  ['PKPI', 'perintah'],
#  ['PDIP', 'pihak'],
#  ['Nasdem', 'pihak'],
#  ['PAN', 'pihak'],
#  ['Garuda', 'pihak'],
#  ['PBB', 'tingkat'],
#  ['Hanura', 'pihak'],
#  ['Demokrat', 'perintah'],
#  ['PPP', 'dprd'],
#  ['PSI', 'dprd'],
#  ['PKB', 'dprd'],
#  ['Nasdem', 'dprd'],
#  ['Gerindra', 'dprd'],
#  ['PAN', 'dprd'],
#  ['Golkar', 'dprd'],
#  ['Berkarya', 'dprd'],
#  ['PDIP', 'dprd'],
#  ['Garuda', 'dprd'],
#  ['PKS', 'fungsi'],
#  ['Hanura', 'dprd'],
#  ['Demokrat', 'dprd'],
#  ['PKPI', 'dprd'],
#  ['PBB', 'dprd']]

# %%
dfpartaikata4 = df[['partai','kata4']]
#dfpartaikata2clean = dfpartaikata2[df['kata2'].notna()]
dfpartaikata4clean = dfpartaikata4.dropna()
dfpartaikata4clean
listpartaikata4 = dfpartaikata4clean.values.tolist()
listpartaikata4
# Out:
# [['Demokrat', 'masyarakat'],
#  ['Nasdem', 'masyarakat'],
#  ['Gerindra', 'utara'],
#  ['Golkar', 'utara'],
#  ['PKS', 'utara'],
#  ['PPP', 'utara'],
#  ['PKB', 'utara'],
#  ['PSI', 'utara'],
#  ['PAN', 'utara'],
#  ['PKPI', 'utara'],
#  ['Garuda', 'utara'],
#  ['Hanura', 'utara'],
#  ['Berkarya', 'utara'],
#  ['PDIP', 'utara'],
#  ['PBB', 'masyarakat'],
#  ['Gerindra', 'perintah'],
#  ['Berkarya', 'perintah'],
#  ['PKS', 'perintah'],
#  ['PKB', 'perintah'],
#  ['Golkar', 'perintah'],
#  ['PSI', 'perintah'],
#  ['PPP', 'perintah'],
#  ['PKPI', 'perintah'],
#  ['PDIP', 'perintah'],
#  ['Nasdem', 'perintah'],
#  ['PAN', 'perintah'],
#  ['Garuda', 'perintah'],
#  ['PBB', 'tingkat'],
#  ['Hanura', 'perintah'],
#  ['Demokrat', 'perintah'],
#  ['PPP', 'fungsi'],
#  ['PSI', 'fungsi'],
#  ['PKB', 'fungsi'],
#  ['Nasdem', 'fungsi'],
#  ['Gerindra', 'fungsi'],
#  ['PAN', 'fungsi'],
#  ['Golkar', 'fungsi'],
#  ['Berkarya', 'fungsi'],
#  ['PDIP', 'fungsi'],
#  ['Garuda', 'fungsi'],
#  ['PKS', 'fungsi'],
#  ['Hanura', 'fungsi'],
#  ['Demokrat', 'fungsi'],
#  ['PKPI', 'fungsi'],
#  ['PBB', 'fungsi']]

# %%
g.add_edges_from(listpartaikata0,weight=1, label="partaikata0edge")
g.add_edges_from(listpartaikata1,weight=1, label="partaikata1edge")
g.add_edges_from(listpartaikata2,weight=1, label="partaikata2edge")
g.add_edges_from(listpartaikata3,weight=1, label="partaikata3edge")
g.add_edges_from(listpartaikata4,weight=1, label="partaikata3edge")

# %%
labels = [i for i in dict(g.nodes).keys()]
labels = {i:i for i in dict(g.nodes).keys()}
labels
labelsclean = {k: v for k, v in labels.items() if pd.Series(v).notna().all()}
labelsclean
# Out:
# {'Pembangunan Daerah': 'Pembangunan Daerah',
#  'masyarakat': 'masyarakat',
#  'utara': 'utara',
#  'Pergerakan Nasional': 'Pergerakan Nasional',
#  'perintah': 'perintah',
#  'tingkat': 'tingkat',
#  'Peran Anggota Legislatif': 'Peran Anggota Legislatif',
#  'fungsi': 'fungsi',
#  'Demokrat': 'Demokrat',
#  'juang': 'juang',
#  'Nasdem': 'Nasdem',
#  'Gerindra': 'Gerindra',
#  'Golkar': 'Golkar',
#  'PKS': 'PKS',
#  'PPP': 'PPP',
#  'PKB': 'PKB',
#  'PSI': 'PSI',
#  'PAN': 'PAN',
#  'PKPI': 'PKPI',
#  'Garuda': 'Garuda',
#  'Hanura': 'Hanura',
#  'Berkarya': 'Berkarya',
#  'PDIP': 'PDIP',
#  'PBB': 'PBB',
#  'provinsi': 'provinsi',
#  'bidang': 'bidang',
#  'bangun': 'bangun',
#  'hak': 'hak',
#  'pihak': 'pihak',
#  'dprd': 'dprd'}

# %%
fig, ax = plt.subplots(figsize=(19,15))
layout = nx.spring_layout(g,iterations=50)
nx.draw_networkx_nodes(g, layout, ax = ax, labels = True)
nx.draw_networkx_edges(g, layout, ax = ax)
_ = nx.draw_networkx_labels(g, layout, labels, ax=ax)
partaipopuler = [namapartai for namapartai in df.partai if g.degree(namapartai) > 1]
nx.draw_networkx_nodes(g, layout, nodelist=partaipopuler, node_color='orange', node_size=150)

# %%
# Precompute probabilities and generate walks
node2vec = Node2Vec(g, dimensions=50, walk_length=16, num_walks=100, workers=4)
# Out:
# Computing transition probabilities: 100%|████████████████████████████████████████████| 30/30 [00:00<00:00, 1074.34it/s]

# %%
# EmbedQ
model = node2vec.fit(window=10, min_count=1, batch_words=4)  # Any keywords acceptable by gensim.Word2Vec can be passed, `diemnsions` and `workers` are automatically passed (from the Node2Vec constructor)

# %%
df.partai
# Out:
# 0     Demokrat
# 1       Nasdem
# 2     Gerindra
# 3       Golkar
# 4          PKS
# 5          PPP
# 6          PKB
# 7          PSI
# 8          PAN
# 9         PKPI
# 10      Garuda
# 11      Hanura
# 12    Berkarya
# 13        PDIP
# 14         PBB
# 15    Gerindra
# 16    Berkarya
# 17         PKS
# 18         PKB
# 19      Golkar
# 20         PSI
# 21         PPP
# 22        PKPI
# 23        PDIP
# 24      Nasdem
# 25         PAN
# 26      Garuda
# 27         PBB
# 28      Hanura
# 29    Demokrat
# 30         PPP
# 31         PSI
# 32         PKB
# 33      Nasdem
# 34    Gerindra
# 35         PAN
# 36      Golkar
# 37    Berkarya
# 38        PDIP
# 39      Garuda
# 40         PKS
# 41      Hanura
# 42    Demokrat
# 43        PKPI
# 44         PBB
# Name: partai, dtype: object

# %%
used = set()
nodepartai = [x for x in df.partai if x not in used and (used.add(x) or True)]
#nodepartai = set(nodepartai)
nodepartai
# Out:
# ['Demokrat',
#  'Nasdem',
#  'Gerindra',
#  'Golkar',
#  'PKS',
#  'PPP',
#  'PKB',
#  'PSI',
#  'PAN',
#  'PKPI',
#  'Garuda',
#  'Hanura',
#  'Berkarya',
#  'PDIP',
#  'PBB']

# %%
nodepartai2 = [x for x in df.partai]
nodepartai2
# Out:
# ['Demokrat',
#  'Nasdem',
#  'Gerindra',
#  'Golkar',
#  'PKS',
#  'PPP',
#  'PKB',
#  'PSI',
#  'PAN',
#  'PKPI',
#  'Garuda',
#  'Hanura',
#  'Berkarya',
#  'PDIP',
#  'PBB',
#  'Gerindra',
#  'Berkarya',
#  'PKS',
#  'PKB',
#  'Golkar',
#  'PSI',
#  'PPP',
#  'PKPI',
#  'PDIP',
#  'Nasdem',
#  'PAN',
#  'Garuda',
#  'PBB',
#  'Hanura',
#  'Demokrat',
#  'PPP',
#  'PSI',
#  'PKB',
#  'Nasdem',
#  'Gerindra',
#  'PAN',
#  'Golkar',
#  'Berkarya',
#  'PDIP',
#  'Garuda',
#  'PKS',
#  'Hanura',
#  'Demokrat',
#  'PKPI',
#  'PBB']

# %%
nodekategori = [x for x in df.kategori]
#nodepartai = set(nodepartai)
nodekategori
# Out:
# ['Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pembangunan Daerah',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Pergerakan Nasional',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif',
#  'Peran Anggota Legislatif']

# %%
used = set()
#uniq = ['PARTAI_KEADILAN_SEJAHTERA']
uniq2 = [x for x in nodepartai if x not in used and (used.add(x) or True)]
uniq2
# Out:
# ['Demokrat',
#  'Nasdem',
#  'Gerindra',
#  'Golkar',
#  'PKS',
#  'PPP',
#  'PKB',
#  'PSI',
#  'PAN',
#  'PKPI',
#  'Garuda',
#  'Hanura',
#  'Berkarya',
#  'PDIP',
#  'PBB']

# %%
embeddings = np.array([model.wv[x] for x in nodepartai2])
embeddings
# Out:
# array([[-0.09156831, -0.47981924,  0.06638294, ..., -0.13216919,
#          0.00342942,  0.12578842],
#        [-0.09151676, -0.47467896,  0.08169364, ..., -0.12592907,
#          0.00917755,  0.1145797 ],
#        [-0.08697331, -0.48729265,  0.09377956, ..., -0.12617113,
#          0.01319264,  0.12229499],
#        ...,
#        [-0.09156831, -0.47981924,  0.06638294, ..., -0.13216919,
#          0.00342942,  0.12578842],
#        [-0.0841884 , -0.47146443,  0.07162383, ..., -0.12904301,
#          0.00123251,  0.12015758],
#        [-0.07168956, -0.48052064,  0.08116215, ..., -0.12612934,
#          0.01093249,  0.11687563]], dtype=float32)

# %%
tsne = TSNE(n_components=2, random_state=7, perplexity=15)
embeddings_2d = tsne.fit_transform(embeddings)

# %%
warna_kategori = {
    'Pembangunan Daerah':'lightsalmon',
    'Pergerakan Nasional':'palegreen',
    'Peran Anggota Legislatif':'blue'}
    #'Partai_Keadilan_Sejahtera':'yellow',
    #'Partai_Kebangkitan_Bangsa':'darkcyan',
    #'Partai_Persatuan_Pembangunan':'steelblue'}

df['color'] = df['kategori'].apply(lambda x: warna_kategori[x])
warna_partai=dict(zip(df['partai'],df['color']))
colors = [warna_kategori[x] for x in df.kategori]

# %%
figure = plt.figure(figsize=(11,9))

ax = figure.add_subplot(111)

ax.scatter(embeddings_2d[:,0], embeddings_2d[:,1], c=colors)

i = 0
for partaiku in nodepartai2:
    ax.annotate(partaiku, (embeddings_2d[i,0], embeddings_2d[i, 1]))
    i=i+1
    

partai_legend=[mpatches.Patch(color=color, label=df.partai.unique()) for df.partai, color in warna_kategori.items()]
ax.legend(handles=partai_legend);

# %%
import matplotlib.pyplot as plt
pos = nx.spring_layout(g)
node_color = [20000.0 * g.degree(v) for v in g]
node_size =  [v * 100 for v in degree_dict.values()]
plt.figure(figsize=(20,20))
nx.draw_networkx(g, pos=pos, with_labels=True,node_color=node_color,node_size=node_size )
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-656b85745c20> in <module>
#       2 pos = nx.spring_layout(g)
#       3 node_color = [20000.0 * g.degree(v) for v in g]
# ----> 4 node_size =  [v * 100 for v in degree_dict.values()]
#       5 plt.figure(figsize=(20,20))
#       6 nx.draw_networkx(g, pos=pos, with_labels=True,node_color=node_color,node_size=node_size )
#
# NameError: name 'degree_dict' is not defined
